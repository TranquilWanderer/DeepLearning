# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from dnn_app_utils import *
from L_layers_model import *
from skimage.transform import resize

# 载入数据集
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# 重构训练样本和测试样本
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# 标准化数值特征，使其在0-1之间
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

# 设置神经网络层数与节点数
layer_dims = [12288,20,7,5,1]

# %%
# 训练神经网络
parameters = L_layers_model(train_x,train_y,layer_dims,learning_rate=0.0075,num_iterations=3000,print_cost=True)
pred_train = predict(train_x, train_y, parameters)
# Out:
# Cost after iteration 0: 0.662626644619374
# Cost after iteration 100: 0.5960028766985187
# Cost after iteration 200: 0.537031264894866
# Cost after iteration 300: 0.3674263476413287
# Cost after iteration 400: 0.27143240373415756
# Cost after iteration 500: 0.2118004391258025
# Cost after iteration 600: 0.13120595084893005
# Cost after iteration 700: 0.07838725902704566
# Cost after iteration 800: 0.05169084562000735
# Cost after iteration 900: 0.03140454987031766
# Cost after iteration 1000: 0.019390382142916565
# Cost after iteration 1100: 0.014728705475337996
# Cost after iteration 1200: 0.011718608141482621
# Cost after iteration 1300: 0.009647267650850503
# Cost after iteration 1400: 0.008134440827992948
# Cost after iteration 1500: 0.006988067472190552
# Cost after iteration 1600: 0.006093738476691778
# Cost after iteration 1700: 0.005378282263552516
# Cost after iteration 1800: 0.0047944742480447895
# Cost after iteration 1900: 0.0043141069956827965
# ...

# %%
# 预测神经网络
pred_test = predict(test_x, test_y, parameters)
# Out:
# 准确度为：0.72

# %%
## START CODE HERE ##
classes = np.array(["non-cat", "cat"])
my_image = "my.jpg" # change this to the name of your image file
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)
## END CODE HERE ##

fname = my_image
my_image = np.array(image.resize((num_px,num_px)).reshape((num_px*num_px*3,1))
my_predicted_image = predict(my_image, my_label_y, parameters)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + str(classes[int(np.squeeze(my_predicted_image))]) +  "\" picture.")
# Out:
#   Cell In[18], line 8
#     my_image = np.array(image.resize(num_px,num_px).reshape((num_px*num_px*3,1))
#                        ^
# SyntaxError: '(' was never closed
